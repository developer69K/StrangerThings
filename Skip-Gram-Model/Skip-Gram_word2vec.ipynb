# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:10])
# Out:
# [5233, 3083, 11, 5, 194, 1, 3133, 45, 58, 155]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
def subsampling(t, int_words):
    c = Counter(int_words)
    newlist=[]
    total_count=len(int_words)
    freq = {word : count/total_count for word, count in c.items()}
    for w in int_words:
        val = 1-np.sqrt(t/freq[w])
        if val<random.random():newlist.append(w)
    train_words = newlist
    return train_words

# %%
t = 1e-5
train_words = subsampling(t, int_words=int_words)

# %% [raw]
# train_words[:20]

# %%
print(len(int_words))
print(len(train_words))
# Out:
# 16680599
# 4628844

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R=random.randint(1,window_size+1)
    if idx-R>0:toret=set(words[idx-R:idx]+words[idx+1:idx+1+R])
    else:toret=set(words[0:idx]+words[idx+1:idx+1+R])
    
    return list(toret)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 3
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/3 Iteration: 100 Avg. Training loss: 5.6788 0.2562 sec/batch
# Epoch 1/3 Iteration: 200 Avg. Training loss: 5.6393 0.2553 sec/batch
# Epoch 1/3 Iteration: 300 Avg. Training loss: 5.5228 0.2564 sec/batch
# Epoch 1/3 Iteration: 400 Avg. Training loss: 5.6238 0.2543 sec/batch
# Epoch 1/3 Iteration: 500 Avg. Training loss: 5.5232 0.2546 sec/batch
# Epoch 1/3 Iteration: 600 Avg. Training loss: 5.5606 0.2551 sec/batch
# Epoch 1/3 Iteration: 700 Avg. Training loss: 5.5595 0.2561 sec/batch
# Epoch 1/3 Iteration: 800 Avg. Training loss: 5.5633 0.2577 sec/batch
# Epoch 1/3 Iteration: 900 Avg. Training loss: 5.4885 0.2621 sec/batch
# Epoch 1/3 Iteration: 1000 Avg. Training loss: 5.4731 0.2652 sec/batch
# Nearest to is: borrows, hoosiers, jungian, decss, pathologic, szl, tribal, mumonkan,
# Nearest to were: separation, patterson, compost, lenoir, stratovolcano, salerno, saga, bw,
# Nearest to by: arbitration, maid, mans, explicit, dufresne, foiling, warnings, adhemar,
# Nearest to known: ucla, pascal, casale, kremlin, reification, flirting, cholerae, mushroom,
# Nearest to some: skanderbeg, weighed, dates, unlawfully, perspective, adolph, mortuary, nodens,
# Nearest to five: cupid, branson, theft, catalogues, metallized, branes, kagan, treasury,
# Nearest to all: mumy, clippings, funds, shuster, textures, ta, additionally, synthesised,
# Nearest to can: informal, kutch, eightfold, atlantis, sos, fishing, colossians, lehi,
# Nearest to professional: tenders, terror, legalized, resourceful, stripping, spinning, supranationalism, sporadic,
# Nearest to ocean: mask, gliese, dien, streymoy, pli, sulpicius, abbate, toonopedia,
# Nearest to grand: distinctions, bronstein, commence, kista, vikrant, sideband, ribald, runtime,
# Nearest to hold: bullpen, war, bokken, gamblers, boogaloo, senex, brillig, nabataean,
# Nearest to notes: petrograd, mems, koblenz, heighten, masefield, captivated, omne, debian,
# Nearest to writers: angrily, yachts, additivity, hucknall, atwood, combed, cantor, shawnee,
# Nearest to alternative: harder, remained, imams, nanotechnology, famines, tornadoes, pursuers, portions,
# Nearest to pope: dewolf, curate, conspirator, redux, nimrod, apertura, casper, kampen,
# Epoch 1/3 Iteration: 1100 Avg. Training loss: 5.4898 0.2725 sec/batch
# Epoch 1/3 Iteration: 1200 Avg. Training loss: 5.3866 0.2694 sec/batch
# Epoch 1/3 Iteration: 1300 Avg. Training loss: 5.3397 0.2719 sec/batch
# Epoch 1/3 Iteration: 1400 Avg. Training loss: 5.2359 0.2711 sec/batch
# Epoch 1/3 Iteration: 1500 Avg. Training loss: 5.1876 0.2723 sec/batch
# Epoch 1/3 Iteration: 1600 Avg. Training loss: 5.1303 0.2732 sec/batch
# Epoch 1/3 Iteration: 1700 Avg. Training loss: 5.0789 0.2754 sec/batch
# Epoch 1/3 Iteration: 1800 Avg. Training loss: 5.0506 0.2748 sec/batch
# Epoch 1/3 Iteration: 1900 Avg. Training loss: 5.0065 0.2749 sec/batch
# Epoch 1/3 Iteration: 2000 Avg. Training loss: 4.9618 0.2764 sec/batch
# Nearest to is: borrows, tribal, came, hoosiers, find, continuous, szl, underway,
# Nearest to were: separation, patterson, out, samuel, reluctance, bistable, saga, vested,
# Nearest to by: explicit, current, to, encyclopedia, warnings, maid, lived, second,
# Nearest to known: ucla, pascal, kremlin, casale, flirting, etc, inflation, reification,
# Nearest to some: perspective, weighed, dates, skanderbeg, commercial, referred, also, genetic,
# Nearest to five: branson, cupid, killed, infant, theft, treasury, mark, place,
# Nearest to all: textures, funds, additionally, debate, yan, involving, synthesised, passages,
# Nearest to can: informal, will, fishing, religions, honor, make, eightfold, legendary,
# Nearest to professional: terror, publishing, legalized, tenders, spinning, sporadic, hunt, stripping,
# Nearest to ocean: mask, gliese, residing, dien, episodes, festivals, owned, educational,
# Nearest to grand: distinctions, commence, bronstein, runtime, most, ribald, kista, civilize,
# Nearest to hold: war, bullpen, bokken, gamblers, changes, pertaining, timberlake, reproductive,
# Nearest to notes: petrograd, koblenz, mems, heighten, circulates, partially, welcome, omne,
# Nearest to writers: cantor, atwood, angrily, yachts, kingdoms, trigger, hucknall, recycled,
# Nearest to alternative: remained, harder, nanotechnology, imams, tornadoes, golden, portions, privateer,
# Nearest to pope: dewolf, curate, apertura, kicker, opted, kampen, conspirator, casper,
# Epoch 1/3 Iteration: 2100 Avg. Training loss: 4.9089 0.2822 sec/batch
# Epoch 1/3 Iteration: 2200 Avg. Training loss: 4.9131 0.2783 sec/batch
# Epoch 1/3 Iteration: 2300 Avg. Training loss: 4.8808 0.2803 sec/batch
# Epoch 1/3 Iteration: 2400 Avg. Training loss: 4.8785 0.2795 sec/batch
# Epoch 1/3 Iteration: 2500 Avg. Training loss: 4.8119 0.2775 sec/batch
# Epoch 1/3 Iteration: 2600 Avg. Training loss: 4.8252 0.2799 sec/batch
# Epoch 1/3 Iteration: 2700 Avg. Training loss: 4.7994 0.2793 sec/batch
# Epoch 1/3 Iteration: 2800 Avg. Training loss: 4.7886 0.2789 sec/batch
# Epoch 1/3 Iteration: 2900 Avg. Training loss: 4.8013 0.2793 sec/batch
# Epoch 1/3 Iteration: 3000 Avg. Training loss: 4.7764 0.2807 sec/batch
# Nearest to is: borrows, tribal, szl, continuous, hoosiers, find, came, provost,
# Nearest to were: separation, patterson, isl, employers, emphasised, reluctance, stratovolcano, saga,
# Nearest to by: maid, explicit, to, warnings, arbitration, encyclopedia, transistor, commons,
# Nearest to known: pascal, ucla, kremlin, casale, reification, flirting, inflation, misguided,
# Nearest to some: perspective, weighed, arguably, skanderbeg, dates, shortages, mortuary, adolph,
# Nearest to five: infant, cupid, killed, theft, branson, gordon, catalogues, treasury,
# Nearest to all: funds, textures, ta, passages, synthesised, additionally, mumy, bursts,
# Nearest to can: informal, will, eightfold, fishing, legendary, make, allowance, religions,
# Nearest to professional: spinning, terror, publishing, stripping, tenders, legalized, sporadic, affinity,
# Nearest to ocean: mask, gliese, residing, dien, episodes, rumors, owned, pli,
# Nearest to grand: distinctions, commence, bronstein, runtime, crank, kista, burnham, surrenders,
# Nearest to hold: war, bullpen, gamblers, bokken, reproductive, dramas, pertaining, roberts,
# Nearest to notes: petrograd, koblenz, mems, circulates, narrowly, heighten, facilitate, partially,
# Nearest to writers: cantor, angrily, atwood, violinist, recycled, yachts, trigger, sitting,
# Nearest to alternative: harder, remained, nanotechnology, golden, imams, portions, tornadoes, wikiquote,
# Nearest to pope: curate, opted, apertura, dewolf, kicker, cretan, conspirator, kampen,
# Epoch 1/3 Iteration: 3100 Avg. Training loss: 4.7780 0.2841 sec/batch
# Epoch 1/3 Iteration: 3200 Avg. Training loss: 4.7510 0.2816 sec/batch
# Epoch 1/3 Iteration: 3300 Avg. Training loss: 4.7013 0.2819 sec/batch
# Epoch 1/3 Iteration: 3400 Avg. Training loss: 4.6962 0.2807 sec/batch
# Epoch 1/3 Iteration: 3500 Avg. Training loss: 4.7192 0.2853 sec/batch
# Epoch 1/3 Iteration: 3600 Avg. Training loss: 4.7048 0.2831 sec/batch
# Epoch 1/3 Iteration: 3700 Avg. Training loss: 4.6973 0.2852 sec/batch
# Epoch 1/3 Iteration: 3800 Avg. Training loss: 4.7304 0.2813 sec/batch
# Epoch 1/3 Iteration: 3900 Avg. Training loss: 4.7243 0.2834 sec/batch
# Epoch 1/3 Iteration: 4000 Avg. Training loss: 4.6495 0.2819 sec/batch
# Nearest to is: borrows, hoosiers, continuous, find, tribal, szl, underway, sidra,
# Nearest to were: separation, isl, patterson, stratovolcano, reluctance, employers, lenoir, amendments,
# Nearest to by: arbitration, to, maid, warnings, remedies, deductions, nuclear, lived,
# Nearest to known: pascal, ucla, casale, reification, theirs, kremlin, inflation, misguided,
# Nearest to some: perspective, weighed, skanderbeg, unlawfully, mortuary, arguably, factorize, dates,
# Nearest to five: infant, killed, gordon, two, branson, cupid, theft, six,
# Nearest to all: ta, textures, involving, synthesised, funds, mumy, additionally, yan,
# Nearest to can: will, lasers, informal, eightfold, sos, allowance, make, kutch,
# Nearest to professional: spinning, tenders, terror, publishing, sporadic, stripping, hunt, affinity,
# Nearest to ocean: mask, gliese, dien, reorganisation, oau, pli, episodes, residing,
# Nearest to grand: distinctions, commence, bronstein, dewitt, kista, surrenders, crashing, seven,
# Nearest to hold: war, dramas, bullpen, bokken, gamblers, reproductive, spd, pertaining,
# Nearest to notes: petrograd, heighten, mems, koblenz, circulates, implausible, narrowly, bud,
# Nearest to writers: additivity, cantor, bombings, angrily, yachts, atwood, fiction, recycled,
# Nearest to alternative: harder, remained, nanotechnology, tornadoes, wikiquote, golden, imams, famines,
# Nearest to pope: conspirator, curate, opted, kampen, apertura, cretan, dewolf, kicker,
# Epoch 1/3 Iteration: 4100 Avg. Training loss: 4.6643 0.2834 sec/batch
# Epoch 1/3 Iteration: 4200 Avg. Training loss: 4.6474 0.2827 sec/batch
# Epoch 1/3 Iteration: 4300 Avg. Training loss: 4.6100 0.2842 sec/batch
# Epoch 1/3 Iteration: 4400 Avg. Training loss: 4.6502 0.2838 sec/batch
# Epoch 1/3 Iteration: 4500 Avg. Training loss: 4.6509 0.2821 sec/batch
# Epoch 1/3 Iteration: 4600 Avg. Training loss: 4.6444 0.2821 sec/batch
# Epoch 2/3 Iteration: 4700 Avg. Training loss: 4.6124 0.2048 sec/batch
# Epoch 2/3 Iteration: 4800 Avg. Training loss: 4.5734 0.2845 sec/batch
# Epoch 2/3 Iteration: 4900 Avg. Training loss: 4.5297 0.2831 sec/batch
# Epoch 2/3 Iteration: 5000 Avg. Training loss: 4.5172 0.2828 sec/batch
# Nearest to is: borrows, continuous, hoosiers, find, tribal, pathologic, light, jungian,
# Nearest to were: separation, isl, employers, reluctance, lenoir, stratovolcano, salerno, amendments,
# Nearest to by: arbitration, to, maid, remedies, jtf, lived, boopsie, encyclopedia,
# Nearest to known: pascal, reification, casale, theirs, kremlin, ucla, flirting, minneapolis,
# Nearest to some: perspective, form, skanderbeg, acids, weighed, mortuary, unlawfully, factorize,
# Nearest to five: infant, two, gordon, branson, killed, cupid, george, six,
# Nearest to all: ta, passages, textures, synthesised, mumy, foam, involving, shuster,
# Nearest to can: lasers, will, informal, sos, eightfold, dirac, make, invariant,
# Nearest to professional: spinning, publishing, tenders, hunt, eschewing, stripping, yhwh, bystander,
# Nearest to ocean: oau, dien, mask, reorganisation, pli, sulpicius, gliese, xiang,
# Nearest to grand: dewitt, commence, bronstein, laney, distinctions, surrenders, seven, kista,
# Nearest to hold: bokken, war, dramas, gamblers, bullpen, nabataean, reproductive, uncial,
# Nearest to notes: petrograd, heighten, mems, circulates, koblenz, facilitate, welcome, captivated,
# Nearest to writers: additivity, cantor, angrily, yachts, bombings, fiction, atwood, shawnee,
# Nearest to alternative: harder, nanotechnology, remained, tornadoes, wikiquote, golden, imams, famines,
# Nearest to pope: conspirator, curate, cretan, frederick, nimrod, kampen, ito, apertura,
# Epoch 2/3 Iteration: 5100 Avg. Training loss: 4.4928 0.2873 sec/batch
# Epoch 2/3 Iteration: 5200 Avg. Training loss: 4.5083 0.2819 sec/batch
# Epoch 2/3 Iteration: 5300 Avg. Training loss: 4.4687 0.2836 sec/batch
# Epoch 2/3 Iteration: 5400 Avg. Training loss: 4.5315 0.2819 sec/batch
# Epoch 2/3 Iteration: 5500 Avg. Training loss: 4.5067 0.2824 sec/batch
# Epoch 2/3 Iteration: 5600 Avg. Training loss: 4.4773 0.2847 sec/batch
# Epoch 2/3 Iteration: 5700 Avg. Training loss: 4.4567 0.2843 sec/batch
# Epoch 2/3 Iteration: 5800 Avg. Training loss: 4.4062 0.2842 sec/batch
# Epoch 2/3 Iteration: 5900 Avg. Training loss: 4.4418 0.2851 sec/batch
# Epoch 2/3 Iteration: 6000 Avg. Training loss: 4.4164 0.2840 sec/batch
# Nearest to is: continuous, borrows, jungian, hoosiers, correct, containing, find, pathologic,
# Nearest to were: separation, employers, isl, salerno, lenoir, reluctance, stratovolcano, invaded,
# Nearest to by: arbitration, to, maid, remedies, jtf, deductions, boopsie, lived,
# Nearest to known: reification, pascal, kremlin, casale, theirs, flirting, stephan, minneapolis,
# Nearest to some: form, perspective, genetic, nodens, unlawfully, factorize, skanderbeg, consequences,
# Nearest to five: two, infant, branson, gordon, killed, zero, africanus, kagan,
# Nearest to all: ta, passages, involving, textures, pain, brier, yan, lamia,
# Nearest to can: lasers, informal, will, make, continuous, sos, eightfold, invariant,
# Nearest to professional: spinning, publishing, tenders, hunt, padres, eschewing, yhwh, stripping,
# Nearest to ocean: oau, dien, xiang, pli, hudson, eilean, othniel, es,
# Nearest to grand: dewitt, commence, bronstein, laney, tabulate, crashing, surrenders, fathoms,
# Nearest to hold: bokken, bullpen, gamblers, dramas, nabataean, war, pertaining, ippon,
# Nearest to notes: heighten, mems, petrograd, omne, koblenz, circulates, welcome, debian,
# Nearest to writers: additivity, fiction, cantor, angrily, yachts, bombings, atwood, giordano,
# Nearest to alternative: harder, nanotechnology, tornadoes, wikiquote, golden, remained, imams, statistic,
# Nearest to pope: conspirator, curate, cretan, kampen, nimrod, frederick, apertura, ito,
# Epoch 2/3 Iteration: 6100 Avg. Training loss: 4.4280 0.2888 sec/batch
# Epoch 2/3 Iteration: 6200 Avg. Training loss: 4.4290 0.2844 sec/batch
# Epoch 2/3 Iteration: 6300 Avg. Training loss: 4.4573 0.2841 sec/batch
# Epoch 2/3 Iteration: 6400 Avg. Training loss: 4.3777 0.2845 sec/batch
# Epoch 2/3 Iteration: 6500 Avg. Training loss: 4.3988 0.2821 sec/batch
# Epoch 2/3 Iteration: 6600 Avg. Training loss: 4.4440 0.2852 sec/batch
# Epoch 2/3 Iteration: 6700 Avg. Training loss: 4.3825 0.2832 sec/batch
# Epoch 2/3 Iteration: 6800 Avg. Training loss: 4.3741 0.2836 sec/batch
# Epoch 2/3 Iteration: 6900 Avg. Training loss: 4.4084 0.2824 sec/batch
# Epoch 2/3 Iteration: 7000 Avg. Training loss: 4.3875 0.2844 sec/batch
# Nearest to is: continuous, borrows, hoosiers, urpmi, correct, marginally, find, containing,
# Nearest to were: separation, employers, isl, lenoir, emphasised, reluctance, salerno, prospered,
# Nearest to by: arbitration, to, remedies, margrethe, maid, lived, jtf, dufresne,
# Nearest to known: pascal, reification, theirs, kremlin, flirting, mushroom, casale, stephan,
# Nearest to some: form, nodens, perspective, unlawfully, mortuary, factorize, skanderbeg, genetic,
# Nearest to five: two, branson, gordon, infant, zero, six, cupid, africanus,
# Nearest to all: passages, involving, ta, tatian, textures, trademark, dichotomy, nanomachines,
# Nearest to can: lasers, informal, continuous, injection, make, sos, dirac, will,
# Nearest to professional: spinning, publishing, tenders, hunt, eschewing, padres, organon, monday,
# Nearest to ocean: oau, dien, hudson, es, othniel, eilean, pli, xiang,
# Nearest to grand: dewitt, laney, commence, tabulate, bronstein, fathoms, crashing, glazer,
# Nearest to hold: bokken, gamblers, dramas, bullpen, pertaining, nabataean, war, reproductive,
# Nearest to notes: heighten, omne, circulates, koblenz, welcome, mems, bilge, fullwidth,
# Nearest to writers: fiction, additivity, cantor, atwood, angrily, yachts, giordano, aviator,
# Nearest to alternative: harder, nanotechnology, tornadoes, wikiquote, remained, coset, golden, hortatory,
# Nearest to pope: conspirator, curate, kampen, cretan, frederick, nimrod, viii, apertura,
# Epoch 2/3 Iteration: 7100 Avg. Training loss: 4.3592 0.2855 sec/batch
# Epoch 2/3 Iteration: 7200 Avg. Training loss: 4.3996 0.2816 sec/batch
# Epoch 2/3 Iteration: 7300 Avg. Training loss: 4.3599 0.2829 sec/batch
# Epoch 2/3 Iteration: 7400 Avg. Training loss: 4.3671 0.2820 sec/batch
# Epoch 2/3 Iteration: 7500 Avg. Training loss: 4.3889 0.2815 sec/batch
# Epoch 2/3 Iteration: 7600 Avg. Training loss: 4.3761 0.2829 sec/batch
# Epoch 2/3 Iteration: 7700 Avg. Training loss: 4.3958 0.2828 sec/batch
# Epoch 2/3 Iteration: 7800 Avg. Training loss: 4.3790 0.2833 sec/batch
# Epoch 2/3 Iteration: 7900 Avg. Training loss: 4.3218 0.2844 sec/batch
# Epoch 2/3 Iteration: 8000 Avg. Training loss: 4.3276 0.2829 sec/batch
# Nearest to is: continuous, borrows, marginally, urpmi, hoosiers, correct, botulism, words,
# Nearest to were: separation, invaded, isl, lenoir, stratovolcano, reluctance, prospered, employers,
# Nearest to by: arbitration, to, remedies, margrethe, second, nuclear, inflows, lived,
# Nearest to known: reification, theirs, kremlin, wadden, pascal, mushroom, flirting, diffraction,
# Nearest to some: form, mortuary, nodens, consequences, genetic, perspective, versuch, citywide,
# Nearest to five: two, six, zero, infant, branson, gordon, four, africanus,
# Nearest to all: ta, passages, lamia, involving, tatian, emissaries, brier, nanomachines,
# Nearest to can: lasers, informal, injection, readable, continuous, dirac, will, make,
# Nearest to professional: publishing, spinning, padres, tenders, organon, hunt, monday, career,
# Nearest to ocean: oau, dien, es, othniel, hudson, eilean, northeast, xiang,
# Nearest to grand: laney, commence, bronstein, dewitt, glazer, tabulate, crashing, kista,
# Nearest to hold: bokken, gamblers, dramas, pertaining, bullpen, nabataean, thessalonians, war,
# Nearest to notes: heighten, welcome, omne, circulates, bilge, firmware, mems, koblenz,
# Nearest to writers: fiction, additivity, cantor, angrily, yachts, atwood, giordano, ian,
# Nearest to alternative: harder, nanotechnology, wikiquote, tornadoes, coset, minimax, hortatory, golden,
# Nearest to pope: conspirator, curate, cretan, kampen, viii, frederick, nimrod, apertura,
# Epoch 2/3 Iteration: 8100 Avg. Training loss: 4.3511 0.2900 sec/batch
# Epoch 2/3 Iteration: 8200 Avg. Training loss: 4.2745 0.2865 sec/batch
# Epoch 2/3 Iteration: 8300 Avg. Training loss: 4.3935 0.2836 sec/batch
# Epoch 2/3 Iteration: 8400 Avg. Training loss: 4.3877 0.2842 sec/batch
# Epoch 2/3 Iteration: 8500 Avg. Training loss: 4.4139 0.2828 sec/batch
# Epoch 2/3 Iteration: 8600 Avg. Training loss: 4.3140 0.2835 sec/batch
# Epoch 2/3 Iteration: 8700 Avg. Training loss: 4.3033 0.2803 sec/batch
# Epoch 2/3 Iteration: 8800 Avg. Training loss: 4.3409 0.2822 sec/batch
# Epoch 2/3 Iteration: 8900 Avg. Training loss: 4.2382 0.2839 sec/batch
# Epoch 2/3 Iteration: 9000 Avg. Training loss: 4.2901 0.2833 sec/batch
# Nearest to is: continuous, urpmi, hoosiers, marginally, borrows, inhabitant, sidra, jungian,
# Nearest to were: separation, isl, prospered, employers, invaded, domesday, serbs, reluctance,
# Nearest to by: arbitration, to, nuclear, remedies, second, margrethe, inflows, gol,
# Nearest to known: reification, theirs, kremlin, minneapolis, pascal, stephan, wadden, aar,
# Nearest to some: form, mortuary, nodens, citywide, genetic, versuch, factorize, ejaculate,
# Nearest to five: two, zero, six, infant, four, gordon, branson, eight,
# Nearest to all: ta, passages, emissaries, lamia, involving, brier, nanomachines, sumatran,
# Nearest to can: informal, lasers, injection, dirac, readable, make, conforms, continuous,
# Nearest to professional: padres, spinning, publishing, tenders, hunt, organon, mumonkan, career,
# Nearest to ocean: oau, dien, eilean, pli, xiang, rocks, es, hudson,
# Nearest to grand: laney, bronstein, commence, dewitt, surrenders, glazer, tabulate, kista,
# Nearest to hold: bokken, gamblers, pertaining, dramas, bullpen, nabataean, kripke, thessalonians,
# Nearest to notes: heighten, fullwidth, omne, bilge, welcome, mach, firmware, circulates,
# Nearest to writers: fiction, cantor, additivity, novelists, ian, buckminster, atwood, yachts,
# Nearest to alternative: harder, nanotechnology, wikiquote, minimax, remained, golden, coset, tornadoes,
# Nearest to pope: conspirator, curate, cretan, viii, frederick, kampen, nimrod, xvi,
# Epoch 2/3 Iteration: 9100 Avg. Training loss: 4.3154 0.2865 sec/batch
# Epoch 2/3 Iteration: 9200 Avg. Training loss: 4.3120 0.2824 sec/batch
# Epoch 3/3 Iteration: 9300 Avg. Training loss: 4.3431 0.1255 sec/batch
# Epoch 3/3 Iteration: 9400 Avg. Training loss: 4.2595 0.2828 sec/batch
# Epoch 3/3 Iteration: 9500 Avg. Training loss: 4.2334 0.2834 sec/batch
# Epoch 3/3 Iteration: 9600 Avg. Training loss: 4.2462 0.2839 sec/batch
# Epoch 3/3 Iteration: 9700 Avg. Training loss: 4.2371 0.2825 sec/batch
# Epoch 3/3 Iteration: 9800 Avg. Training loss: 4.2187 0.2844 sec/batch
# Epoch 3/3 Iteration: 9900 Avg. Training loss: 4.2441 0.2833 sec/batch
# Epoch 3/3 Iteration: 10000 Avg. Training loss: 4.1888 0.2826 sec/batch
# Nearest to is: continuous, marginally, urpmi, inhabitant, many, hoosiers, borrows, stretches,
# Nearest to were: separation, prospered, domesday, isl, invaded, lycia, lenoir, fealty,
# Nearest to by: to, arbitration, nuclear, second, remedies, gol, inflows, gamemaster,
# Nearest to known: theirs, reification, kremlin, aar, minneapolis, possibly, normalize, wadden,
# Nearest to some: form, nodens, mortuary, genetic, versuch, citywide, factorize, consenting,
# Nearest to five: two, zero, six, four, gordon, infant, branson, africanus,
# Nearest to all: ta, emissaries, lamia, sumatran, trademark, yan, nanomachines, passages,
# Nearest to can: lasers, informal, injection, make, dirac, continuous, conforms, gloves,
# Nearest to professional: publishing, spinning, padres, users, tenders, organon, monday, affinity,
# Nearest to ocean: oau, eilean, es, rocks, dien, pli, xiang, residing,
# Nearest to grand: laney, glazer, dewitt, commence, bronstein, kista, grau, tabulate,
# Nearest to hold: gamblers, bokken, nabataean, bullpen, pertaining, thessalonians, dramas, brillig,
# Nearest to notes: fullwidth, heighten, omne, welcome, bilge, koblenz, mach, bear,
# Nearest to writers: fiction, cantor, novelists, additivity, retells, yachts, buckminster, discourse,
# Nearest to alternative: harder, nanotechnology, wikiquote, minimax, hyphens, coset, golden, hortatory,
# Nearest to pope: conspirator, curate, cretan, viii, kampen, nimrod, xvi, frederick,
# Epoch 3/3 Iteration: 10100 Avg. Training loss: 4.2672 0.2875 sec/batch
# Epoch 3/3 Iteration: 10200 Avg. Training loss: 4.2485 0.2848 sec/batch
# Epoch 3/3 Iteration: 10300 Avg. Training loss: 4.2404 0.2849 sec/batch
# Epoch 3/3 Iteration: 10400 Avg. Training loss: 4.1195 0.2859 sec/batch
# Epoch 3/3 Iteration: 10500 Avg. Training loss: 4.1877 0.2857 sec/batch
# Epoch 3/3 Iteration: 10600 Avg. Training loss: 4.1992 0.2861 sec/batch
# Epoch 3/3 Iteration: 10700 Avg. Training loss: 4.1774 0.2851 sec/batch
# Epoch 3/3 Iteration: 10800 Avg. Training loss: 4.1793 0.2849 sec/batch
# Epoch 3/3 Iteration: 10900 Avg. Training loss: 4.2390 0.2854 sec/batch
# Epoch 3/3 Iteration: 11000 Avg. Training loss: 4.1810 0.2859 sec/batch
# Nearest to is: continuous, marginally, urpmi, cos, many, jungian, inhabitant, words,
# Nearest to were: separation, isl, prospered, domesday, lycia, invaded, fealty, lenoir,
# Nearest to by: to, arbitration, second, margrethe, nuclear, remedies, gol, gamemaster,
# Nearest to known: theirs, reification, aar, possibly, kremlin, pascal, ui, mushroom,
# Nearest to some: form, nodens, factorize, genetic, versuch, mortuary, retrospectively, acids,
# Nearest to five: two, zero, six, four, infant, eight, africanus, gordon,
# Nearest to all: ta, nanomachines, passages, emissaries, lamia, sumatran, railtrack, trademark,
# Nearest to can: lasers, informal, injection, make, gloves, dirac, readable, backplane,
# Nearest to professional: padres, spinning, publishing, organon, defunct, users, monday, tenders,
# Nearest to ocean: oau, eilean, rocks, pli, es, residing, dien, cedar,
# Nearest to grand: laney, glazer, commence, bronstein, grau, fathoms, kista, dewitt,
# Nearest to hold: gamblers, bokken, pertaining, nabataean, thessalonians, dramas, bullpen, brillig,
# Nearest to notes: fullwidth, heighten, welcome, omne, mach, bear, bilge, firmware,
# Nearest to writers: fiction, cantor, novelists, additivity, atwood, retells, yachts, angrily,
# Nearest to alternative: harder, nanotechnology, wikiquote, minimax, remained, hortatory, hyphens, coset,
# Nearest to pope: conspirator, cretan, curate, viii, kampen, nimrod, damnation, xvi,
# Epoch 3/3 Iteration: 11100 Avg. Training loss: 4.1795 0.2885 sec/batch
# Epoch 3/3 Iteration: 11200 Avg. Training loss: 4.2186 0.2847 sec/batch
# Epoch 3/3 Iteration: 11300 Avg. Training loss: 4.1740 0.2847 sec/batch
# Epoch 3/3 Iteration: 11400 Avg. Training loss: 4.1672 0.2832 sec/batch
# Epoch 3/3 Iteration: 11500 Avg. Training loss: 4.1857 0.2837 sec/batch
# Epoch 3/3 Iteration: 11600 Avg. Training loss: 4.2003 0.2842 sec/batch
# Epoch 3/3 Iteration: 11700 Avg. Training loss: 4.1988 0.2845 sec/batch
# Epoch 3/3 Iteration: 11800 Avg. Training loss: 4.2025 0.2815 sec/batch
# Epoch 3/3 Iteration: 11900 Avg. Training loss: 4.1164 0.2842 sec/batch
# Epoch 3/3 Iteration: 12000 Avg. Training loss: 4.2086 0.2838 sec/batch
# Nearest to is: continuous, urpmi, many, marginally, words, unrelated, inhabitant, borrows,
# Nearest to were: prospered, separation, isl, domesday, invaded, lycia, lenoir, jsf,
# Nearest to by: to, arbitration, second, nuclear, margrethe, remedies, pill, inflows,
# Nearest to known: reification, theirs, wadden, aar, possibly, pascal, ui, mushroom,
# Nearest to some: nodens, form, genetic, factorize, mortuary, also, retrospectively, versuch,
# Nearest to five: two, zero, six, four, infant, eight, one, gordon,
# Nearest to all: ta, nanomachines, emissaries, lamia, railtrack, sumatran, passages, tatian,
# Nearest to can: lasers, informal, injection, make, dirac, readable, lehi, continuous,
# Nearest to professional: padres, spinning, organon, publishing, users, affinity, defunct, programs,
# Nearest to ocean: eilean, oau, residing, rocks, pli, es, satellite, coaxial,
# Nearest to grand: laney, commence, glazer, summoned, suns, kista, bronstein, fundamento,
# Nearest to hold: gamblers, bokken, pertaining, nabataean, thessalonians, brillig, dramas, bullpen,
# Nearest to notes: fullwidth, welcome, omne, mach, heighten, phonology, bear, cliches,
# Nearest to writers: fiction, novelists, cantor, additivity, retells, atwood, discourse, angrily,
# Nearest to alternative: harder, nanotechnology, wikiquote, weblog, minimax, coset, golden, remained,
# Nearest to pope: conspirator, cretan, curate, viii, kampen, nimrod, xvi, damnation,
# Epoch 3/3 Iteration: 12100 Avg. Training loss: 4.2070 0.2867 sec/batch
# Epoch 3/3 Iteration: 12200 Avg. Training loss: 4.1960 0.2833 sec/batch
# Epoch 3/3 Iteration: 12300 Avg. Training loss: 4.2081 0.2825 sec/batch
# Epoch 3/3 Iteration: 12400 Avg. Training loss: 4.1722 0.2830 sec/batch
# Epoch 3/3 Iteration: 12500 Avg. Training loss: 4.1440 0.2858 sec/batch
# Epoch 3/3 Iteration: 12600 Avg. Training loss: 4.1379 0.2840 sec/batch
# Epoch 3/3 Iteration: 12700 Avg. Training loss: 4.1804 0.2854 sec/batch
# Epoch 3/3 Iteration: 12800 Avg. Training loss: 4.1158 0.2875 sec/batch
# Epoch 3/3 Iteration: 12900 Avg. Training loss: 4.1946 0.2850 sec/batch
# Epoch 3/3 Iteration: 13000 Avg. Training loss: 4.2096 0.2844 sec/batch
# Nearest to is: continuous, urpmi, inhabitant, hoosiers, many, words, marginally, establishes,
# Nearest to were: prospered, isl, domesday, separation, invaded, serbs, lycia, stratovolcano,
# Nearest to by: to, arbitration, margrethe, of, second, nuclear, sincerely, inflows,
# Nearest to known: reification, theirs, ui, kremlin, aar, carne, wadden, possibly,
# Nearest to some: nodens, form, mortuary, also, citywide, bantu, retrospectively, versuch,
# Nearest to five: two, six, zero, four, eight, infant, gordon, one,
# Nearest to all: ta, emissaries, railtrack, lamia, commemorates, nanomachines, sumatran, brier,
# Nearest to can: informal, lasers, readable, injection, eightfold, dirac, lehi, backplane,
# Nearest to professional: padres, organon, publishing, spinning, monday, affinity, dealer, career,
# Nearest to ocean: eilean, oau, coaxial, satellite, pli, residing, rocks, intelsat,
# Nearest to grand: laney, summoned, commence, glazer, bronstein, kista, suns, fundamento,
# Nearest to hold: gamblers, bokken, pertaining, nabataean, thessalonians, brillig, bullpen, cactus,
# Nearest to notes: fullwidth, cliches, heighten, welcome, maji, omne, bear, elvis,
# Nearest to writers: fiction, novelists, cantor, retells, atwood, discourse, additivity, buckminster,
# Nearest to alternative: harder, nanotechnology, wikiquote, weblog, minimax, golden, coset, hyphens,
# Nearest to pope: conspirator, cretan, curate, viii, kampen, xvi, nimrod, redux,
# Epoch 3/3 Iteration: 13100 Avg. Training loss: 4.2489 0.2872 sec/batch
# Epoch 3/3 Iteration: 13200 Avg. Training loss: 4.1486 0.2856 sec/batch
# Epoch 3/3 Iteration: 13300 Avg. Training loss: 4.1436 0.2820 sec/batch
# Epoch 3/3 Iteration: 13400 Avg. Training loss: 4.1498 0.2824 sec/batch
# Epoch 3/3 Iteration: 13500 Avg. Training loss: 4.0239 0.2824 sec/batch
# Epoch 3/3 Iteration: 13600 Avg. Training loss: 4.1429 0.2843 sec/batch
# Epoch 3/3 Iteration: 13700 Avg. Training loss: 4.1809 0.2821 sec/batch
# Epoch 3/3 Iteration: 13800 Avg. Training loss: 4.1502 0.2819 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
